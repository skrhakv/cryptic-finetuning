# %% [markdown]
# ## CAUTION
# You need to add a libraries from a [separate project](https://github.com/skrhakv/pocket-movement-analysis/blob/master/src/utils/biotite_utils.py) (update the `sys.path.append(...)` path).

# %%
from biotite.structure import distance
import numpy as np  
import os
import sys
from biotite.structure import superimpose
import biotite
import biotite.database.rcsb as rcsb
import os
from biotite.structure.io.pdbx import get_structure
import biotite.structure.io.pdbx as pdbx
from biotite.sequence import ProteinSequence

sys.path.append('/home/vit/Projects/flexibility-analysis/src/utils')
import biotite_utils
import dataset_utils

# %%
CIF_FILES_PATH = '/home/vit/Projects/deeplife-project/data/cif_files'


##########################################################################################################################
#                                                                                                                        #
# This is mostly coppied from https://github.com/skrhakv/pocket-movement-analysis/blob/master/src/utils/biotite_utils.py #
#                                                                                                                        #
##########################################################################################################################

mapping = {'Aba': 'A', 'Ace': 'X', 'Acr': 'X', 'Ala': 'A', 'Aly': 'K', 'Arg': 'R', 'Asn': 'N', 'Asp': 'D', 'Cas': 'C',
           'Ccs': 'C', 'Cme': 'C', 'Csd': 'C', 'Cso': 'C', 'Csx': 'C', 'Cys': 'C', 'Dal': 'A', 'Dbb': 'T', 'Dbu': 'T',
           'Dha': 'S', 'Gln': 'Q', 'Glu': 'E', 'Gly': 'G', 'Glz': 'G', 'His': 'H', 'Hse': 'S', 'Ile': 'I', 'Leu': 'L',
           'Llp': 'K', 'Lys': 'K', 'Men': 'N', 'Met': 'M', 'Mly': 'K', 'Mse': 'M', 'Nh2': 'X', 'Nle': 'L', 'Ocs': 'C',
           'Pca': 'E', 'Phe': 'F', 'Pro': 'P', 'Ptr': 'Y', 'Sep': 'S', 'Ser': 'S', 'Thr': 'T', 'Tih': 'A', 'Tpo': 'T',
           'Trp': 'W', 'Tyr': 'Y', 'Unk': 'X', 'Val': 'V', 'Ycm': 'C', 'Sec': 'U', 'Pyl': 'O', 'Mhs': 'H', 'Snm': 'S',
           'Mis': 'S', 'Seb': 'S', 'Hic': 'H', 'Fme': 'M', 'Asb': 'D', 'Sah': 'C', 'Smc': 'C', 'Tpq': 'Y', 'Onl': 'X',
           'Tox': 'W', '5x8': 'X', 'Ddz': 'A'}


def three_to_one(three_letter_code):
    if three_letter_code[0].upper() + three_letter_code[1:].lower() not in mapping:
        return 'X'
    return mapping[three_letter_code[0].upper() + three_letter_code[1:].lower()]

def get_sequence(protein):
    sequence = ''.join([three_to_one(residue.res_name) for residue in protein])
    return ProteinSequence(sequence)



def get_protein_backbone(id, indices=None):
    pdb_id = id[:4]
    chain_id = id[4:]

    cif_file_path = rcsb.fetch(pdb_id, "cif", CIF_FILES_PATH)

    cif_file = pdbx.CIFFile.read(cif_file_path)

    protein = get_structure(cif_file, model=1)

    protein_backbone = protein[(protein.chain_id == chain_id) & (biotite.structure.filter_peptide_backbone(protein))]
    # the following code taken from the biotite source code:
    # https://github.com/biotite-dev/biotite/blob/v0.41.0/src/biotite/structure/residues.py#L22
    chain_id_changes = (protein_backbone.chain_id[1:] != protein_backbone.chain_id[:-1])
    res_id_changes   = (protein_backbone.res_id[1:]   != protein_backbone.res_id[:-1]  )
    ins_code_changes = (protein_backbone.ins_code[1:] != protein_backbone.ins_code[:-1])
    res_name_changes = (protein_backbone.res_name[1:] != protein_backbone.res_name[:-1])
    residue_change_mask = (
        chain_id_changes |
        res_id_changes |
        ins_code_changes |
        res_name_changes
    )

    residue_starts = np.where(residue_change_mask)[0] + 1
    residue_starts = np.concatenate(([0], residue_starts))

    # take the C_alphas if possible (now we have the N atoms, however, regularly the C_alphas are located right behind the N atoms, so increase the indices by 1)
    if len(protein_backbone) > residue_starts[-1] + 1:
        residue_starts = residue_starts + 1

    protein_backbone = protein_backbone[residue_starts]

    if indices:
        return protein_backbone[indices]
    
    return protein_backbone

##########################################################################################################################
#                                                                                                                        #
#                                                                                                                        #
#                                                                                                                        #
##########################################################################################################################

def compute_distances():
    dataset_path = f'../cryptobench-dataset/dataset.json'
    output_path = f'../data/residue-distances'
    sequence_path = f'../data/sequences'
    
    dataset = dataset_utils.load_subset(dataset_path)
    apo_holo_pairs = dataset_utils.load_main_apo_holo_pairs(dataset, multichain=False)

    for apo, holo in apo_holo_pairs.items():
        print(f'Processing {apo}:{holo}')

        # Some random biotite error for those pairs; I don't have the mental capacity to deal with this - skipping
        # if apo == "8j1kA" and holo == "3ouiA":
        #     continue
        # if apo == "8pfpA" and holo == "7gquA":
        #     continue
        if apo == "5lgrB" or apo == "8h6pA":
            continue

        if os.path.exists(f'{output_path}/{apo}.npy'):
            continue

        apo_backbone = get_protein_backbone(apo)
        apo_sequence = get_sequence(apo_backbone)

        holo_backbone = get_protein_backbone(holo)
        holo_sequence = get_sequence(holo_backbone)

        alignment = biotite_utils.align_sequences(apo_sequence, holo_sequence)

        # we need to filter out the non-matching residues, otherwise the superimpose function will fail
        apo_indices = [i[0] for i in alignment[0].trace]
        holo_indices = [i[1] for i in alignment[0].trace]

        # get the structures with respect to indices
        apo_backbone = get_protein_backbone(apo, indices=apo_indices)
        holo_backbone = get_protein_backbone(holo, indices=holo_indices)

        holo_backbone, _ = superimpose(apo_backbone, holo_backbone)

        # rerun the alignment - the indices might got shifted due to the filtering for the sake of superimposing
        apo_sequence = get_sequence(apo_backbone)
        holo_sequence = get_sequence(holo_backbone)

        # print(f'Length of apo sequence: {len(apo_sequence)}, Length of holo sequence: {len(holo_sequence)}')
        alignment = biotite_utils.align_sequences(apo_sequence, holo_sequence)

        # get mapping of indices from the filtered structure to the structure that matches the data from fluctuation:
        original_apo_backbone = get_protein_backbone(apo)
        # print(f'Length of original apo backbone: {len(original_apo_backbone)}')
        # print(f'Length of indiced apo backbone: {len(apo_backbone)}')
        original_apo_residue_ids = [residue.res_id for residue in original_apo_backbone]
        # print(original_apo_residue_ids)
        # print([residue.res_id for i, residue in enumerate(apo_backbone)])
        res_id_to_index = {i: original_apo_residue_ids.index(residue.res_id) for i, residue in enumerate(apo_backbone)}

        distances = np.full(len(original_apo_backbone), -1, dtype=np.float16)

        for i in alignment[0].trace:
            apo_index, holo_index = i
            # print(apo_index)
            # print(res_id_to_index[apo_index])
            distances[res_id_to_index[apo_index]] = distance(apo_backbone[apo_index], holo_backbone[holo_index])

        with open(f'{sequence_path}/{apo}.txt', 'r') as file:
            sequence = file.read()

        assert len(sequence) == len(distances), f'{apo}: {len(sequence)} != {len(distances)}'
        np.save(f'{output_path}/{apo}.npy', distances)

compute_distances()

# TODO:
# 1. napsat report z tohohle meetingu (viz dole)
# 2. proc se to nespocitalo pro vsechny??? pouze 933 z 946
# 3. zkusit ten multitask learning (mean square logarithm loss? zni lepe nez MSE ale je potreba zkusit oboji I guess)


# rigid (funguji grafovky opravdu hur? rozsirit threshold na 8A)
# multitask
# analyza chyb (jak daleko jsou chyby - jsou blizko, jestli jsou na povrchu/uvnitr, jestli jsou na static vazebnem miste, Metrika od Yany)
# dataset rozsireni
#
# Out:
# Processing 1a4uB:3rj9C
# Processing 1a8dA:1diwA
# Processing 1ad1A:6clvC
# Processing 1ak1A:2q2oA
# Processing 1arlA:3cpaA
# Processing 1aylA:6at3B
# Processing 1b0iA:1g9hA
# Processing 1bfnA:1bybA
# Processing 1bhsA:1i5rA
# Processing 1bk2A:5ihkA
# Processing 1byiA:1dakA
# Processing 1bzjA:5qelA
# Processing 1c3kA:1c3nA
# Processing 1cuzA:1xzcA
# Processing 1cwqA:1xjiA
# Processing 1dc6A:6utmB
# Processing 1dklA:7z2sA
# Processing 1dpjA:2jxrA
# Processing 1dq2A:1qdcA
# Processing 1dqzA:5vnsA
# Processing 1dteA:4n8sA
# Processing 1e3gA:4k7aA
# Processing 1e5lB:1e5qB
# Processing 1e6kA:3rvrA
# Processing 1eccB:1ecfA
# Processing 1efhB:3f3yA
# Processing 1eswA:5jiwA
# Processing 1evyA:1n1eB
# Processing 1ezlC:3iboC
# Processing 1f47B:1s1sB
# Processing 1f8aB:4tyoB
# Processing 1fd9A:8bjdA
# Processing 1fdpA:1dfpA
# Processing 1ffhA:2cnwA
# Processing 1fl1B:4p3hB
# Processing 1fvrA:6mweA
# Processing 1fwkC:1h72C
# Processing 1g24C:2a9kB
# Processing 1g59A:1j09A
# Processing 1gqnA:1qfeA
# Processing 1gqzA:2gkeA
# Processing 1h13A:2b4fA
# Processing 1h3gB:3edfA
# Processing 1havA:1qa7C
# Processing 1hbqA:1kt3A
# Processing 1hp1A:4wwlA
# Processing 1ht6A:1rpkA
# Processing 1i0rB:1i0sA
# Processing 1i7nA:1i7lA
# Processing 1iwlA:7z6xA
# Processing 1j8fC:4y6qB
# Processing 1jpmA:1tkkB
# Processing 1k0nA:7fbqA
# Processing 1k1xB:1k1yA
# Processing 1k47D:3gonA
# Processing 1k4kD:1k4mA
# Processing 1k7kA:2q16A
# Processing 1kg5A:1mudA
# Processing 1kn9D:6b88A
# Processing 1ks9A:2ofpB
# Processing 1ksgB:4jv6B
# Processing 1kx9A:1n8vB
# Processing 1kxrA:2g8jA
# Processing 1l0wB:1g51A
# Processing 1lbeB:3i9lA
# Processing 1ljuA:1rxeA
# Processing 1lugA:5jqtA
# Processing 1m1zA:1mc1B
# Processing 1m5wD:1ixnA
# Processing 1macB:1u0aA
# Processing 1mhnA:7w2pA
# Processing 1ms4B:3pjqA
# Processing 1mufA:4jdsA
# Processing 1mwkA:2zgzA
# Processing 1mwrA:1mwtB
# Processing 1n05A:1n08A
# Processing 1nbfB:8d4zA
# Processing 1nd7A:8ei4A
# Processing 1nkoA:2hrlA
# Processing 1nn6A:3s0nA
# Processing 1nokA:1xkxA
# Processing 1nulB:1a95C
# Processing 1nwhB:1pquA
# Processing 1nzoA:3becA
# Processing 1o73A:6gxgC
# Processing 1of3B:1oh4A
# Processing 1oibB:1a54A
# Processing 1omxA:1omzA
# Processing 1os2B:5l79A
# Processing 1p4oB:1jqhA
# Processing 1p4vA:4r4yA
# Processing 1p74A:1p77A
# Processing 1p9oA:7edzC
# Processing 1pfzC:2igxA
# Processing 1pt7A:1q7eA
# Processing 1ptaA:8p7iA
# Processing 1pu5C:2ag2B
# Processing 1px5B:4rwoA
# Processing 1py3C:3d5iB
# Processing 1q4kA:4lklA
# Processing 1qhtA:5omqA
# Processing 1qrzC:8f7vB
# Processing 1r8jA:4g86B
# Processing 1rf5D:1rf6C
# Processing 1rjbA:6jqrA
# Processing 1rkmA:2rkmA
# Processing 1rq2B:6ym1A
# Processing 1rtcA:4q2vA
# Processing 1rxdC:5bx1A
# Processing 1s2lC:1s2dB
# Processing 1s8cC:3hokB
# Processing 1se8A:3udgC
# Processing 1sh0A:3bsnA
# Processing 1sjsA:1cw4A
# Processing 1sndB:2of1A
# Processing 1sulA:1sviA
# Processing 1t8tA:6xkgA
# Processing 1t9rA:1xozA
# Processing 1thvA:2pe7A
# Processing 1tqdA:1tpzB
# Processing 1tqnA:8so2A
# Processing 1u4pA:1u4mA
# Processing 1uiuA:5on9B
# Processing 1ukaA:1iupA
# Processing 1un1B:1umzB
# Processing 1urpC:1dbpA
# Processing 1uteA:7ov8A
# Processing 1vjuB:3dwrA
# Processing 1vk4A:7e4lA
# Processing 1vr2A:3vhkA
# Processing 1vsnA:6pxfA
# Processing 1wamA:3gf4B
# Processing 1wjgA:2z09A
# Processing 1wxeA:1wxhA
# Processing 1wycA:2dcfA
# Processing 1x0mA:3wx9C
# Processing 1x2gC:4tvyB
# Processing 1xgdA:2pdfA
# Processing 1xhxB:2pyjA
# Processing 1xjfA:1xjjB
# Processing 1xqvA:1xroA
# Processing 1xqzA:3a99A
# Processing 1xtcA:2a5fB
# Processing 1y6iA:7e2sA
# Processing 1yhvA:4zjjA
# Processing 1yl5B:5tjzA
# Processing 1ys0A:1cwsA
# Processing 1z7gD:4racA
# Processing 1z90B:2icyA
# Processing 1zm0A:2i5cB
# Processing 2a88A:1n2eA
# Processing 2airH:1za1D
# Processing 2akaA:1lvkA
# Processing 2akrA:6ojpA
# Processing 2b0jA:3h65A
# Processing 2b23B:2qxsA
# Processing 2b7cA:5o8wA
# Processing 2beiB:2q4vA
# Processing 2bivB:2vytA
# Processing 2bvaA:8ahgA
# Processing 2by3A:2bhzA
# Processing 2c6gA:6h7yA
# Processing 2camA:4jhqA
# Processing 2ci4A:2ci7A
# Processing 2ckqB:7nb3AAA
# Processing 2cl3A:5r4qB
# Processing 2d05A:5hwaA
# Processing 2d0tB:7ngeD
# Processing 2dfpA:6fqnA
# Processing 2dh4B:2e8uB
# Processing 2e1cA:2cyyA
# Processing 2e2oA:2e2qB
# Processing 2e3kB:7l9kA
# Processing 2e3mA:3h3qA
# Processing 2e64B:2dtoA
# Processing 2e8yA:2e8zB
# Processing 2eplX:2epnA
# Processing 2exxB:2wm3A
# Processing 2femA:1kdpB
# Processing 2ffyA:4kz8B
# Processing 2fhzB:2djhA
# Processing 2fimA:3c5nB
# Processing 2fjyA:1dqeB
# Processing 2fk7A:7q2bA
# Processing 2fn9A:2fn8A
# Processing 2fp1A:2fp2B
# Processing 2frsB:4qgxA
# Processing 2fyuD:1ppjD
# Processing 2g5lA:6gmiA
# Processing 2gcbA:1jbwA
# Processing 2gmeB:2gnmA
# Processing 2gzrA:2gzsA
# Processing 2h6dA:3aqvA
# Processing 2h7gX:3igcA
# Processing 2h7sA:4jx1F
# Processing 2h98B:2f7cA
# Processing 2he7A:5rypA
# Processing 2heuC:6prgA
# Processing 2hf0A:8eteB
# Processing 2higA:6qu3A
# Processing 2hq8B:2hpsA
# Processing 2hyyA:5hu9A
# Processing 2i1wB:3v80A
# Processing 2i3aD:7nnrB
# Processing 2i3rA:2i4gA
# Processing 2i6aB:1bx4A
# Processing 2iytA:3bafA
# Processing 2j5iJ:2vssF
# Processing 2jdwA:8jdwA
# Processing 2jfpA:2vvtA
# Processing 2jfyB:4b1fA
# Processing 2jgvC:2jg1C
# Processing 2jlqA:2jlyB
# Processing 2nvpA:5m7iA
# Processing 2nxjA:3cjtG
# Processing 2o8yA:6eg9B
# Processing 2oa6B:5in8B
# Processing 2ofmX:3mvfA
# Processing 2oquA:3e3tA
# Processing 2phzA:2xuzA
# Processing 2pkfA:2pkkA
# Processing 2po4A:4ff4A
# Processing 2pryA:2ps1A
# Processing 2psfB:7omrA
# Processing 2pwoB:4inbA
# Processing 2pwzG:1ib6A
# Processing 2qbvA:2w1aC
# Processing 2qg5D:3f3zA
# Processing 2qsuA:3lgsA
# Processing 2r57A:2r58A
# Processing 2rfjB:7bjyA
# Processing 2rl7A:2rl9B
# Processing 2v6mD:2xxjD
# Processing 2v8jA:2v8kA
# Processing 2vl2C:4k7nC
# Processing 2vqzF:4nceA
# Processing 2vrkB:2vrqA
# Processing 2w5hA:4a4xA
# Processing 2w6rA:7ac8E
# Processing 2w8nA:2w8qA
# Processing 2w9tA:2w9sB
# Processing 2wetA:2weuA
# Processing 2wgbA:2v57A
# Processing 2wvhX:5tmaA
# Processing 2wvyB:2ww2B
# Processing 2x2sA:2x2tA
# Processing 2x36D:6x27B
# Processing 2x47A:6lh4D
# Processing 2x87A:4yvnA
# Processing 2xbpA:4affA
# Processing 2xc1A:3th0A
# Processing 2xe6A:3zozA
# Processing 2xq0A:2xpzA
# Processing 2xsaA:2xsbA
# Processing 2xtpA:2xtmA
# Processing 2xurB:3bepB
# Processing 2y7aB:6gx1A
# Processing 2yd5A:2yd8A
# Processing 2yjrA:5iuiA
# Processing 2ywbA:2ywcA
# Processing 2yx7A:2e7xA
# Processing 2yygA:2yyjA
# Processing 2yz7C:3w8dA
# Processing 2yzgC:2yzmA
# Processing 2z15B:5ci9A
# Processing 2z6wB:3rclA
# Processing 2zcoA:4ea0A
# Processing 2zf3F:2zf4E
# Processing 2zguA:3wg1B
# Processing 2zj7A:3a70C
# Processing 2zsuB:2e5wA
# Processing 2zvyA:5y3zA
# Processing 3a06B:3a14A
# Processing 3a0xA:3a0tA
# Processing 3a7gA:4w8eA
# Processing 3aarA:4brfA
# Processing 3asyA:3w34A
# Processing 3b49A:5x5mB
# Processing 3b7wA:3dayA
# Processing 3bifA:2bifA
# Processing 3bjpA:4n9vA
# Processing 3bl7B:1st0B
# Processing 3bljB:7f43B
# Processing 3bn9A:6n4tA
# Processing 3brkX:5w5rE
# Processing 3bv9B:4hfpB
# Processing 3cabA:3cz0A
# Processing 3cbjA:6ay2B
# Processing 3chfB:2a3cA
# Processing 3cj1A:4cd3A
# Processing 3cjjA:6xq7B
# Processing 3cvmB:3ut3B
# Processing 3d0rB:3otiA
# Processing 3db3A:4qqdA
# Processing 3dfaA:4y5qA
# Processing 3dfjA:3e0pB
# Processing 3dlmA:8uwpB
# Processing 3dpcB:5c66A
# Processing 3e9pA:7fmoA
# Processing 3eomD:3gqtB
# Processing 3f0fB:3p10A
# Processing 3f4kA:3t0iA
# Processing 3f99A:3bltA
# Processing 3f9fA:6xhnA
# Processing 3ffeA:2x3jB
# Processing 3fixB:3ne7A
# Processing 3flgA:5nv0B
# Processing 3fq8A:2hozA
# Processing 3futA:3fuuA
# Processing 3fzoA:3fztA
# Processing 3g8aA:3g89B
# Processing 3garA:1c2tA
# Processing 3gdgB:7krgA
# Processing 3gl0C:3gl2B
# Processing 3h8aB:6bfyA
# Processing 3hi6A:7kc5A
# Processing 3hsjA:1hq2A
# Processing 3i8sB:3i8xA
# Processing 3idhA:4no7A
# Processing 3iecB:8txyA
# Processing 3ih2A:4i76A
# Processing 3ikwA:3in9A
# Processing 3iunA:3iuqA
# Processing 3jxsC:2y64A
# Processing 3jzgA:7qk4A
# Processing 3k01A:3k02A
# Processing 3kjeA:3kjgA
# Processing 3l15A:6s6jB
# Processing 3lckA:2ofvB
# Processing 3lo7A:3uppA
# Processing 3ly8A:3lyaA
# Processing 3me0A:2xg4A
# Processing 3mo4A:3uesA
# Processing 3mo7A:7ov0A
# Processing 3mp4D:3mp5B
# Processing 3mwgB:3mwfA
# Processing 3mwkA:3nbfB
# Processing 3n2wB:3nfbA
# Processing 3n4uA:6cd7B
# Processing 3naqA:3n7uK
# Processing 3naxA:3orzC
# Processing 3nshB:4gidA
# Processing 3nsuA:4a6kC
# Processing 3nx1B:3nx2A
# Processing 3odnA:6xtzA
# Processing 3ofjA:3ofkD
# Processing 3oguA:6dicA
# Processing 3oicD:3oidA
# Processing 3oy6U:1w12U
# Processing 3p08B:4ot5A
# Processing 3p6eA:7fwsA
# Processing 3pbfA:4wuxA
# Processing 3pgsB:3pguA
# Processing 3pidA:3plnA
# Processing 3psgA:6xcyA
# Processing 3px7A:1cy8A
# Processing 3q6uA:8an8A
# Processing 3qasA:3sgvA
# Processing 3qr9B:4x5dB
# Processing 3qwaB:3qwbA
# Processing 3qwdJ:6n80A
# Processing 3r5sA:3r5tA
# Processing 3rbhA:8pz4A
# Processing 3rj3F:4ontD
# Processing 3rmyD:3obtA
# Processing 3rwoB:3rwmB
# Processing 3rwvA:2evlA
# Processing 3s6wA:8jtnA
# Processing 3sebA:1se3A
# Processing 3sr3A:3t5mA
# Processing 3ssxR:1jhgA
# Processing 3st6C:3rv6B
# Processing 3t8bA:3t8aB
# Processing 3tpeA:3tptB
# Processing 3tpoA:4u54A
# Processing 3u49A:3u4cA
# Processing 3u6kA:8fr3A
# Processing 3ugkA:3uh1A
# Processing 3umiA:5buoA
# Processing 3uyiA:3v0sA
# Processing 3v55A:7ak0A
# Processing 3vc7B:4esoC
# Processing 3vdmB:3t7dB
# Processing 3vgmA:3vglA
# Processing 3vhoB:3ammA
# Processing 3viaB:3aj4A
# Processing 3vjbD:3v66A
# Processing 3vjzA:3wurA
# Processing 3vskB:3vslA
# Processing 3vu2B:7ml5A
# Processing 3vw1A:6ie8A
# Processing 3vzcA:3vzdE
# Processing 3w59D:5mwxB
# Processing 3w90A:7ckjA
# Processing 3wb9C:3wbfA
# Processing 3wdwA:3wduC
# Processing 3wmgA:6a6mA
# Processing 3wxlD:6j9vA
# Processing 3x13A:7s7eA
# Processing 3zhzB:4ooeB
# Processing 4a6pA:4b3dA
# Processing 4aalA:4aanA
# Processing 4aemA:4afdA
# Processing 4akdA:1vboE
# Processing 4amvB:2j6hA
# Processing 4bg8A:4bgbA
# Processing 4brrE:4uxzA
# Processing 4by5B:5aanA
# Processing 4c6bA:8pbmA
# Processing 4cmwB:3wqmA
# Processing 4d1nA:5uo3A
# Processing 4d2oB:6d3gD
# Processing 4d8lA:4di8A
# Processing 4dmzB:4dn0A
# Processing 4dncB:6oinA
# Processing 4e00A:8egfA
# Processing 4e1yA:4f10A
# Processing 4ei8A:4ei7A
# Processing 4eizA:1rb3A
# Processing 4ekfA:4pidA
# Processing 4eshA:4edhA
# Processing 4f0iA:5i8aA
# Processing 4f4iB:2ccjB
# Processing 4f5hB:2d5yA
# Processing 4f7dB:4fk8A
# Processing 4fkmB:4filA
# Processing 4gf1B:4fxqA
# Processing 4gi3A:4hx2A
# Processing 4gojC:7umoB
# Processing 4goyA:6i16A
# Processing 4gpiC:5y2iB
# Processing 4gu8H:4gk9A
# Processing 4gv9A:7v38B
# Processing 4gvrA:4gvqA
# Processing 4hc4A:5wcfA
# Processing 4honB:5phkA
# Processing 4hr7A:2v58A
# Processing 4hyeA:4zmsA
# Processing 4hzrA:5zxbA
# Processing 4i36D:4pfkA
# Processing 4i8yA:4i90A
# Processing 4ianB:6cnhA
# Processing 4ikvA:4ikzA
# Processing 4ilgA:7fmwB
# Processing 4iwsA:7abnA
# Processing 4j2pA:1nfpA
# Processing 4j4eF:2pysA
# Processing 4jaxF:3o8mA
# Processing 4jfrC:4jhxA
# Processing 4jmiA:4l5mA
# Processing 4jycC:4jybA
# Processing 4k76C:5ic3A
# Processing 4k86A:7y28A
# Processing 4klxA:5ujfA
# Processing 4kmyA:4kn0A
# Processing 4ku8A:5jd7A
# Processing 4l7kC:6uaeA
# Processing 4la5A:3v1vA
# Processing 4lg4D:8a66A
# Processing 4ljpA:6sc5A
# Processing 4m23B:4m25A
# Processing 4m66A:6okoB
# Processing 4m7pA:2iyfB
# Processing 4mowA:7v0hA
# Processing 4mqeA:4ms4A
# Processing 4mwiA:6o5zB
# Processing 4mziA:7b4nA
# Processing 4n4aA:4n49A
# Processing 4n5gB:2p1vA
# Processing 4n8jA:4n8iA
# Processing 4naiA:2yc3A
# Processing 4nb3B:4ijhA
# Processing 4nfcA:4nfdA
# Processing 4ni8D:4l6dA
# Processing 4nogA:5eqcB
# Processing 4nqtA:1h3tB
# Processing 4nqvF:3myzA
# Processing 4o7dA:3vp1A
# Processing 4ok2B:4ojzB
# Processing 4omgA:7ao0B
# Processing 4oqoB:2e0sA
# Processing 4os8B:4imoA
# Processing 4oyzA:4clzA
# Processing 4p2fA:7yz9A
# Processing 4pfsB:5ihpA
# Processing 4pntD:4buvC
# Processing 4pu0B:4ptzC
# Processing 4punA:7a3xA
# Processing 4pvrA:4osxA
# Processing 4pwnA:5wdyB
# Processing 4qasA:4qatB
# Processing 4qc1B:5cq6A
# Processing 4qfkA:4qfnB
# Processing 4qvkB:4ymgA
# Processing 4r0xA:7b9yA
# Processing 4r1mC:4rvnD
# Processing 4r40D:4pwtC
# Processing 4r7tC:5hj5A
# Processing 4rf5A:7ejjD
# Processing 4rieB:4riiA
# Processing 4rjzA:4qsdA
# Processing 4rksA:4rkzA
# Processing 4rpiD:6buvB
# Processing 4rvsA:4rvuD
# Processing 4rvtB:5w5qA
# Processing 4tqrA:2ibkA
# Processing 4trmE:5mtrA
# Processing 4tsnA:4tspB
# Processing 4ttpA:4ttqA
# Processing 4twiA:1m2kA
# Processing 4tyvA:4tz5A
# Processing 4u0mB:4u0nA
# Processing 4uc8A:4uc9D
# Processing 4ud4B:4fh5A
# Processing 4uumA:5a1tB
# Processing 4wbhA:7b9iA
# Processing 4wjxA:6ze8F
# Processing 4x1oA:5bw4B
# Processing 4xbxB:4xdvC
# Processing 4xg2A:3tubA
# Processing 4xmqB:6w3tB
# Processing 4xrgA:4xr4A
# Processing 4xv1B:4xv9A
# Processing 4xzpA:5duxD
# Processing 4ydrA:7f4cA
# Processing 4yegA:5llfD
# Processing 4yynA:7p4sA
# Processing 4z49A:2px6A
# Processing 4z4lA:7d5gA
# Processing 4z7cA:5gmdA
# Processing 4zcsA:7q3wA
# Processing 4zm7A:5kjqA
# Processing 4zoeB:4zoaA
# Processing 5a03A:5a06A
# Processing 5acvB:6kxoA
# Processing 5ae0A:2yp0A
# Processing 5ajoA:5ndfD
# Processing 5ar2B:6es0B
# Processing 5azqA:2nssA
# Processing 5b0eB:5b09A
# Processing 5bcaA:1b9zA
# Processing 5c74A:5h5fA
# Processing 5caaA:3nguB
# Processing 5caeB:2fp4B
# Processing 5cazA:5cb7B
# Processing 5ck1A:5cjzA
# Processing 5csqA:1gmnA
# Processing 5ct4B:5ct6B
# Processing 5cxgD:5aqcB
# Processing 5cxyB:5bo9A
# Processing 5d27A:5d3yA
# Processing 5dcwA:5dbiB
# Processing 5ddtB:5hs2A
# Processing 5dovB:5dozC
# Processing 5duoC:8e7wB
# Processing 5dv9A:5kytA
# Processing 5dzpB:4qr7A
# Processing 5e0vA:3vkxA
# Processing 5ed0C:5ecdA
# Processing 5ellB:5elmC
# Processing 5ey7B:5f0zA
# Processing 5f12A:3b6jB
# Processing 5f2mD:5ff7C
# Processing 5f3kB:5f5rA
# Processing 5f46A:5f48B
# Processing 5f5jA:2xowA
# Processing 5f7qC:5f7rE
# Processing 5fioB:5c7rA
# Processing 5fsuB:5fsxA
# Processing 5ftkA:7puxA
# Processing 5ggcA:5xd4A
# Processing 5ggsZ:5wt9G
# Processing 5gizB:5y89A
# Processing 5gl7A:5goyA
# Processing 5gmoA:5ywnA
# Processing 5gw7B:3w7sB
# Processing 5h61B:5h62B
# Processing 5h9kA:5haeA
# Processing 5hgxA:5xtxA
# Processing 5hijA:5h02A
# Processing 5hkeB:5y7pA
# Processing 5hq8A:7qnrA
# Processing 5hsmA:5x7zA
# Processing 5htoE:2aa3C
# Processing 5i3tE:5g1wA
# Processing 5i59A:6usuA
# Processing 5i5dD:6vdfC
# Processing 5icsC:5l7yA
# Processing 5ighA:5igiA
# Processing 5ihbA:5j0bB
# Processing 5ilkA:5ikhA
# Processing 5ioxA:3gknA
# Processing 5jhtA:4zi0A
# Processing 5k3aA:6qkwB
# Processing 5k7kA:7rl2A
# Processing 5kcgB:5kcyA
# Processing 5kopD:5korC
# Processing 5l02B:5sxrB
# Processing 5l45A:5l4lA
# Processing 5lccA:5lauA
# Processing 5lgrB:5lgqA
# Processing 5locA:1dapB
# Processing 5lorB:5r5iA
# Processing 5lqjC:1h1dA
# Processing 5lsoA:6hipB
# Processing 5lxhB:7aa7A
# Processing 5mbtC:5tcyB
# Processing 5mcaA:4auyA
# Processing 5mf2D:6f2mD
# Processing 5mkbB:5m28A
# Processing 5nchB:5nciA
# Processing 5niaA:3ftvA
# Processing 5ninB:7pu9A
# Processing 5nr9B:2jckA
# Processing 5ny2A:4izuA
# Processing 5nz1G:6r1pA
# Processing 5nzmA:4m2bA
# Processing 5nzxA:5q22A
# Processing 5o1mA:5o1lB
# Processing 5o8bA:6ir7A
# Processing 5ojxA:5ojyA
# Processing 5op0B:6sa0D
# Processing 5rarB:5rb2B
# Processing 5sc2A:2jcrA
# Processing 5t2vA:5t2uC
# Processing 5t7tA:5t7iA
# Processing 5tc0B:7aw1A
# Processing 5th0E:5tguA
# Processing 5tqvA:5u1pA
# Processing 5tviV:7w9aA
# Processing 5u95B:5bsmB
# Processing 5un3A:6n4zA
# Processing 5uxaA:5igzA
# Processing 5uzvZ:5v0aZ
# Processing 5v1yC:5nljB
# Processing 5v2kB:5u6nA
# Processing 5v49A:4mwdB
# Processing 5w5dF:2yoaB
# Processing 5wbmB:6ul7A
# Processing 5wm0A:5wjaD
# Processing 5x1oB:1fgaA
# Processing 5x6zD:5x6yC
# Processing 5xcwX:5dbeX
# Processing 5xvvE:5xw0A
# Processing 5yhbA:5exyA
# Processing 5yj2C:7cucA
# Processing 5yqpA:6bymA
# Processing 5ysbB:5yseA
# Processing 5ytbC:4hawC
# Processing 5z0aB:2ggqA
# Processing 5z18C:6jz7B
# Processing 5z43A:5z46B
# Processing 5z67A:5z69A
# Processing 5z6cA:5z6bA
# Processing 5za4A:5yybA
# Processing 5ze7B:5zfkA
# Processing 5zicB:8ce3A
# Processing 5zj4D:5zj5A
# Processing 5zrnB:3r44A
# Processing 5zv0A:3h1yA
# Processing 6a45B:6a46A
# Processing 6a98C:6a99A
# Processing 6aa3A:8i18B
# Processing 6aceA:5bwlA
# Processing 6aibA:6aicA
# Processing 6aqeB:7pljD
# Processing 6bn5B:6bmrA
# Processing 6btyB:6bu0C
# Processing 6bziC:6bzzA
# Processing 6c4gA:4zl4B
# Processing 6c4tA:6h3fA
# Processing 6cfsA:6cfvA
# Processing 6cjfA:4ighA
# Processing 6co1F:6vipB
# Processing 6cqeB:7siuA
# Processing 6cswC:3op5A
# Processing 6cwmA:6cwnA
# Processing 6cwwB:4it2B
# Processing 6cy1A:6cy5A
# Processing 6czpB:7uwtB
# Processing 6ddlB:2xjbA
# Processing 6dtrA:6dtqA
# Processing 6du4A:2h00A
# Processing 6dz8A:5tw4A
# Processing 6eqjA:3u2uA
# Processing 6esnA:6t4gA
# Processing 6ezrA:6k35B
# Processing 6f4mA:7dytA
# Processing 6f52A:5mx8A
# Processing 6f56B:6ehjB
# Processing 6fc2C:6fc1A
# Processing 6fgjB:6ewzB
# Processing 6fp0A:5y66A
# Processing 6g6yA:3zcwA
# Processing 6g80B:6g7dA
# Processing 6g9zA:6j5sB
# Processing 6gsoC:6gv2B
# Processing 6h1oB:5xhjB
# Processing 6h6kA:4rcyA
# Processing 6heiA:7tuoA
# Processing 6herA:4ma7A
# Processing 6hl0A:4oivA
# Processing 6hr4A:3pbrA
# Processing 6hrvA:6hsjB
# Processing 6i1sA:5s7qA
# Processing 6i5gB:5aluA
# Processing 6ih8C:6ih6A
# Processing 6infA:6inhA
# Processing 6irxA:6is0A
# Processing 6isuA:7yv4A
# Processing 6iu0B:8hh0A
# Processing 6j1hA:6j0pB
# Processing 6j35B:5yneA
# Processing 6jakC:1gz5A
# Processing 6jhmD:7e8pA
# Processing 6jnjA:7cgrC
# Processing 6jp2A:7u0rB
# Processing 6jq9B:6bytA
# Processing 6kscA:6lw8A
# Processing 6ksuA:6ksvB
# Processing 6kx4A:7d1cA
# Processing 6kyqA:5jzjA
# Processing 6l1iB:6l1pC
# Processing 6l61A:7cctA
# Processing 6lgyA:6lgzA
# Processing 6lioB:4v26A
# Processing 6llgA:6llwB
# Processing 6ltfA:6m3sB
# Processing 6m9aA:4uiqA
# Processing 6mkxA:6mloE
# Processing 6n5jB:6fqdA
# Processing 6n95D:6n92F
# Processing 6neiB:6nejB
# Processing 6nflA:5cqhA
# Processing 6o4fH:4x0uD
# Processing 6oahF:3cp6A
# Processing 6opbD:6oghA
# Processing 6owyA:5wo1A
# Processing 6p5bC:4onmB
# Processing 6pj6U:8cgkl
# Processing 6pk5A:6pjwL
# Processing 6plfB:7dkmA
# Processing 6pntA:8sfuB
# Processing 6puvA:6xiyA
# Processing 6pvgA:6pviA
# Processing 6q6jA:6hyjB
# Processing 6q7qA:6q7rA
# Processing 6q8zD:6q91A
# Processing 6qb5D:5qsxD
# Processing 6qflA:6yg6A
# Processing 6qlbC:4wq3B
# Processing 6qpeA:7kp5BA1
# Processing 6ro0G:7sneD
# Processing 6rwdA:6ji6A
# Processing 6rxdA:6rxeB
# Processing 6s3pA:6s3hB
# Processing 6slkC:6sllA
# Processing 6spoA:8brvA
# Processing 6suiA:6sulA
# Processing 6sz4A:6syuA
# Processing 6tbtB:3lbzA
# Processing 6tn3A:6g9vB
# Processing 6twoAAA:8agkAAA
# Processing 6tx0B:6dwkD
# Processing 6tyoB:6p4qA
# Processing 6u9cA:6pubA
# Processing 6up2A:6up4A
# Processing 6ur2A:8scsA
# Processing 6uw3A:6uw5B
# Processing 6vleA:6x5hC
# Processing 6vtgC:5couA
# Processing 6w10A:8hchA
# Processing 6w3cC:4yz9C
# Processing 6x41B:6x6rB
# Processing 6x84A:4aq4A
# Processing 6xl4C:8d76A
# Processing 6xqxB:6xqvA
# Processing 6xueA:7pbyA
# Processing 6ydkA:1z4oB
# Processing 6z6zA:1x89A
# Processing 6zdcA:6zfaAAA
# Processing 7aa2B:6ze5A
# Processing 7alfA:6gl5A
# Processing 7aqbB:6ylcD
# Processing 7autA:7aurA
# Processing 7av9AAA:5rjuA
# Processing 7b6qA:7b60A
# Processing 7bhjA:7bk9A
# Processing 7bn2BBB:4g55A
# Processing 7bp1B:7bpcC
# Processing 7btcB:6bsxC
# Processing 7c1uA:7c1rA
# Processing 7c48A:8xhrC
# Processing 7c63A:7c67A
# Processing 7cehA:5zrrA
# Processing 7ciuA:7ciwA
# Processing 7cluA:7clfB
# Processing 7crmC:7csiA
# Processing 7ctdA:7ctmA
# Processing 7cyrA:7cz2A
# Processing 7d48A:7d4sA
# Processing 7de1A:7uxzAAA
# Processing 7djnA:3a73A
# Processing 7e5qB:6kmmC
# Processing 7ec1B:7vflC
# Processing 7eguA:5yjfA
# Processing 7ejwD:6jdiA
# Processing 7el8A:7ev2A
# Processing 7eryA:7es0A
# Processing 7etxA:7etyB
# Processing 7f0oA:7f0yA
# Processing 7f2mB:6febA
# Processing 7f4yB:3si6A
# Processing 7ft3A:7fsuD
# Processing 7g8eB:7g82B
# Processing 7gosB:7gokA
# Processing 7jhkD:6wmoB
# Processing 7jrbA:7jrwA
# Processing 7js3D:7txa1
# Processing 7k4wA:4bs0B
# Processing 7kayA:7kawB
# Processing 7kndA:7l92V
# Processing 7kqlT:7m41B
# Processing 7l1zB:7l1yA
# Processing 7l5lB:6uboB
# Processing 7l8qA:7u4kA
# Processing 7lpuA:5rpdA
# Processing 7m2gA:1m48B
# Processing 7moiB:7mofA
# Processing 7n6zA:8c8cA
# Processing 7nbzB:8s5bA
# Processing 7nc8D:7nc5D
# Processing 7ndlB:6svmA
# Processing 7nlxA:7nlnB
# Processing 7nteB:7ntdAAA
# Processing 7o1iA:8oqpA
# Processing 7oapEEE:7d30B
# Processing 7oppC:7oprB
# Processing 7oueA:7oliB
# Processing 7oumC:4dx7A
# Processing 7p75AAA:5ekyA
# Processing 7pa0B:8ctsB
# Processing 7pizC:7pjcA
# Processing 7pldB:7plbA
# Processing 7poqA:7pouB
# Processing 7psjA:3vo0A
# Processing 7qluA:3pb5A
# Processing 7qniAAA:7r3dAAA
# Processing 7qoqA:7phoB
# Processing 7qzrD:7z53P
# Processing 7r00AAA:7qxtAAA
# Processing 7r51B:5sdoA
# Processing 7rawA:7rftA
# Processing 7rx7A:5il1A
# Processing 7s2nA:2q2rA
# Processing 7s5gA:5ocaA
# Processing 7se6A:7secA
# Processing 7sfgA:6x9jA
# Processing 7sktB:7skuA
# Processing 7so5A:2bvlA
# Processing 7t4zB:7t5aA
# Processing 7ujrA:2vz6A
# Processing 7uvwN:7uvyN
# Processing 7v8kB:7f9rA
# Processing 7vdaA:6dhqA
# Processing 7vtzA:7vu0B
# Processing 7vvvA:7vvwA
# Processing 7w19A:7w15A
# Processing 7wmyA:7wmzC
# Processing 7wyoB:7wylA
# Processing 7x0fA:7x0eA
# Processing 7x0gB:7x0hA
# Processing 7x0iB:7x0nB
# Processing 7xgfE:6vwcA
# Processing 7xznC:7xzoA
# Processing 7yjcA:5la7A
# Processing 7ymfA:5e7mA
# Processing 7yv0A:7xpsA
# Processing 7ywjA:5n82A
# Processing 7yx7A:7ne7A
# Processing 7zzxB:8crhB
# Processing 8a74A:8a73A
# Processing 8abuB:8abtA
# Processing 8aeqA:8a8tA
# Processing 8aqiB:7snwB
# Processing 8azbA:8ay0C
# Processing 8b9pA:8tosA
# Processing 8bbcA:6zamA
# Processing 8bdiI:4bktF
# Processing 8bp9BBB:2zalB
# Processing 8breB:4mo4C
# Processing 8c3uA:5r8cA
# Processing 8cfbC:8cfoB
# Processing 8cn8C:5snbA
# Processing 8cqlB:6gmnK
# Processing 8dufA:8t8nA
# Processing 8e1jB:8e1vA
# Processing 8elmA:7eraA
# Processing 8evvA:8evxB
# Processing 8ezsB:7wcfA
# Processing 8fmuB:5qsbA
# Processing 8g25H:1ppgE
# Processing 8ghcB:8ghdA
# Processing 8gw3A:2yiyA
# Processing 8h0nB:7ogjB
# Processing 8h27A:8h1bB
# Processing 8h6pA:6q4dA
# Processing 8hs6H:8hs4A
# Processing 8hynA:8hy9A
# Processing 8i7xC:1tg6B
# Processing 8i84B:8i8hA
# Processing 8iasB:8iatC
# Processing 8ixpA:8ixqD
# Processing 8iy0B:8j8oA
# Processing 8j11X:3o7sA
# Processing 8j1kA:3ouiA
# Processing 8jisR:6x19R
# Processing 8jqkA:1y1pA
# Processing 8ogrB:8ogvA
# Processing 8onnE:8aieA
# Processing 8oqpC:7o4tD
# Processing 8pfpA:7gquA
# Processing 8pzmA:8pzyF
# Processing 8r43A:8rbnA
# Processing 8s32A:8bl2A
# Processing 8sc0A:8u9aA
# Processing 8slbA:2bbhA
# Processing 8sxwA:8sybA
# Processing 8t2lA:7ra0A
# Processing 8u3nA:8u2mB
# Processing 8vdyA:6c5fB
# Processing 8vxuB:6wk9E
# Processing 8wl5A:8wl9A
# Processing 9atcA:2h3eA
# Processing 9bhrB:8og8A

# %% [markdown]
# ## Some single-chain APOs don't have single-chain main holo structure
# We will supplement that by using the default value for the whole chain (we used `-1` above in case residue wasn't present in the holo structure).

# %%
for file in os.listdir('/home/vit/Projects/cryptic-nn/data/sequences'):
    if not os.path.exists(f'/home/vit/Projects/cryptic-nn/data/residue-distances/{file.replace(".txt", ".npy")}'):
        with open(f'/home/vit/Projects/cryptic-nn/data/sequences/{file}', 'r') as f:
            sequence = f.read()
        np.save(f'/home/vit/Projects/cryptic-nn/data/residue-distances/{file.replace(".txt", ".npy")}', np.full(len(sequence), -1, dtype=np.float16))
